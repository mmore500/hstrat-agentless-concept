# %%
# %load_ext watermark

# %%
import numpy as np

from pylib._attribute_random_walk import attribute_random_walk
from pylib._build_path import build_path
from pylib._make_seed_coordinates import make_seed_coordinates
from pylib._pathsplot import pathsplot

# %%
# %watermark -diwmuv -iv
# Out:
# Last updated: 2025-03-24T20:26:34.447223+00:00
#
# Python implementation: CPython
# Python version       : 3.10.12
# IPython version      : 7.31.1
#
# Compiler    : GCC 11.4.0
# OS          : Linux
# Release     : 6.8.0-1021-azure
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 4
# Architecture: 64bit
#
# numpy: 1.23.5
#
# Watermark: 2.4.3

# %% [markdown]
# ## Prep Data

# %%
frames = [np.empty((64, 64), dtype=np.uint8) for _ in range(200)]

# %% [markdown]
# ## Example Plot

# %%
seed_coordinates = make_seed_coordinates(
    x_coords=range(8, 65, 16),
    y_coords=range(16, 65, 32),
)

# %%
pathsplot(
    [
        build_path(coordinate, frames, attribute_random_walk)
        for coordinate in seed_coordinates
    ],
    xmax=64,
    ymax=64,
    col_wrap=4,
)
